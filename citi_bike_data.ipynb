# %% [markdown]
# # Data Source:  https://www.citibikenyc.com/system-data

# %%
# Import dependencies
import pandas as pd

# %%
# Read csv file into pandas
file = "Resources/201306-citibike-tripdata.csv"
df = pd.read_csv(file)
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           695  6/1/2013 0:00  6/1/2013 0:11               444
# 1           693  6/1/2013 0:00  6/1/2013 0:11               444
# 2          2059  6/1/2013 0:00  6/1/2013 0:35               406
# 3           123  6/1/2013 0:01  6/1/2013 0:03               475
# 4          1521  6/1/2013 0:01  6/1/2013 0:26              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
#    end station id        end station name  end station latitude  \
# ...

# %%
# Determine data types
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
# Drop na values from dataframe
df = df.dropna()

# %%
# View dataframe
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           695  6/1/2013 0:00  6/1/2013 0:11               444
# 1           693  6/1/2013 0:00  6/1/2013 0:11               444
# 3           123  6/1/2013 0:01  6/1/2013 0:03               475
# 4          1521  6/1/2013 0:01  6/1/2013 0:26              2008
# 6          2057  6/1/2013 0:02  6/1/2013 0:36               285
#
#       start station name  start station latitude  start station longitude  \
# 0     Broadway & W 24 St               40.742354               -73.989151
# 1     Broadway & W 24 St               40.742354               -73.989151
# 3    E 15 St & Irving Pl               40.735243               -73.987586
# 4  Little West St & 1 Pl               40.705693               -74.016777
# 6     Broadway & E 14 St               40.734546               -73.990741
#
#    end station id     end station name  end station latitude  \
# 0           434.0      9 Ave & W 18 St             40.743174
# ...

# %%
# Save cleaned data to csv
df.to_csv("Resources/bike_info.csv")
